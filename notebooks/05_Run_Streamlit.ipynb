# %%
! pip install streamlit streamlit-option-menu plotly

# %%
import os
print("Current Directory:", os.getcwd())

print("Contents of Directory:", os.listdir())
# Out:
# Current Directory: /Users/hassan/Desktop/IE/Term 3/Capstone/LLM
# Contents of Directory: ['Run_Streamlit.ipynb', 'energy_expert.py', 'daily_data.csv']

# %%
! streamlit run energy_expert.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://192.168.68.181:8501
#
# /Users/hassan/Desktop/IE/Term 3/Capstone/LLM/energy_expert.py:57: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   temp_quantiles = app_data.groupby(pd.qcut(app_data['temp'], 4))['usage'].mean().round(4)
# /Users/hassan/Desktop/IE/Term 3/Capstone/LLM/energy_expert.py:57: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   temp_quantiles = app_data.groupby(pd.qcut(app_data['temp'], 4))['usage'].mean().round(4)
# ...
